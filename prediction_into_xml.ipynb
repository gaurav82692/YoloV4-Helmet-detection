# %%
import cv2 
import numpy as np
from matplotlib import pyplot as plt
from PIL import Image
import os
import xml.etree.ElementTree as ET

CONFIDENCE_THRESHOLD = 0.4
NMS_THRESHOLD = 0.5

# %%
def indent(elem, level=0):
    i = "\n" + level*"  "
    j = "\n" + (level-1)*"  "
    if len(elem):
        if not elem.text or not elem.text.strip():
            elem.text = i + "  "
        if not elem.tail or not elem.tail.strip():
            elem.tail = i
        for subelem in elem:
            indent(subelem, level+1)
        if not elem.tail or not elem.tail.strip():
            elem.tail = j
    else:
        if level and (not elem.tail or not elem.tail.strip()):
            elem.tail = j
    return elem

# %%
class_names = []
with open("coco.names", "r") as f:
    class_names = [cname.strip() for cname in f.readlines()]

# %%
net = cv2.dnn.readNet("custom-yolov4-tiny-detector_best.weights", "custom-yolov4-tiny-detector.cfg")
net.setPreferableBackend(cv2.dnn.DNN_BACKEND_CUDA)
net.setPreferableTarget(cv2.dnn.DNN_TARGET_CUDA_FP16)

# %%
model = cv2.dnn_DetectionModel(net)
model.setInputParams(size=(640, 640), scale=1/255, swapRB=True)

# %%
path = os.path.abspath('test_images')
path
# Out:
# 'C:\\Users\\Gaurav\\Desktop\\wobot assignment\\stage3\\test_images'

# %%
for file in os.listdir(path):
    #root element
    root = ET.Element('annotation')

    #book sub-element
    folder = ET.SubElement(root, 'folder')
    folder.text='Images'

    filename = ET.SubElement(root, 'filename')
    filename.text=file

    size = ET.SubElement(root, 'size')

    width = ET.SubElement(size, 'width')
    width.text = '416'
    height = ET.SubElement(size, 'height')
    height.text = '416'
    depth = ET.SubElement(size, 'depth')
    depth.text = '3'

    segmented = ET.SubElement(root, 'segmented')
    segmented.text='0'
    print(file)
    img = cv2.imread(os.path.join(path, file) )
    classes, scores, boxes = model.detect(img, CONFIDENCE_THRESHOLD, NMS_THRESHOLD)
    for (classid, score, box) in zip(classes, scores, boxes):
        #color=colors[classid[0]]
        score=score[0]
        score=score*100
        score= "{:.2f}".format(score)
        #color=colors[classid[0]]
        #print(score)
        img2=img[box[1]:box[1]+box[3],box[0]:box[0]+box[2]]
        #crop = image[y:y+h, x:x+w]
        x=int((box[2])/2)
        y=int((box[3])/3.5)
        ifa = Image.fromarray(img2)
        color = ifa.getpixel((x,y))
        label = "%s : %s" % (class_names[classid[0]], score+'%')
        #print(label)
        if class_names[classid[0]]=='Head':
            cv2.rectangle(img, box,(0,0,255), 2)
            cv2.putText(img, label, (box[0], box[1] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5,(0,0,255), 2)
        else:
            cv2.rectangle(img, box,color, 2)
            cv2.putText(img, label, (box[0], box[1] - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5,color, 2)
        cv2.imwrite('test_output/'+file,img)
        object = ET.SubElement(root, 'object')
        
        name = ET.SubElement(object, 'name')
        name.text=class_names[classid[0]]

        pose = ET.SubElement(object, 'pose')
        pose.text='Unspecified'

        turncated = ET.SubElement(object, 'turncated')
        turncated.text='0'

        occluded = ET.SubElement(object, 'occluded')
        occluded.text='0'

        difficult = ET.SubElement(object, 'difficult')
        difficult.text='0'

        bndbox = ET.SubElement(object, 'bndbox')

        xmin = ET.SubElement(bndbox, 'xmin')
        xmin.text = str(box[0])

        ymin = ET.SubElement(bndbox, 'ymin')
        ymin.text = str(box[1])

        xmax = ET.SubElement(bndbox, 'xmax')
        xmax.text = str(box[0]+box[2])

        ymax = ET.SubElement(bndbox, 'ymax')
        ymax.text = str(box[1]+box[3])
        
        tree = ET.ElementTree(indent(root))
        tree.write('prediction/'+file[0:-3:]+'xml', xml_declaration=True, encoding='utf-8')
# Out:
# hard_hat_workers1015.png
# hard_hat_workers1018.png
# hard_hat_workers1031.png
# hard_hat_workers1044.png
# hard_hat_workers1068.png
# hard_hat_workers1072.png
# hard_hat_workers1095.png
# hard_hat_workers1102.png
# hard_hat_workers1109.png
# hard_hat_workers1123.png
# hard_hat_workers1188.png
# hard_hat_workers119.png
# hard_hat_workers12.png
# hard_hat_workers121.png
# hard_hat_workers1228.png
# hard_hat_workers1294.png
# hard_hat_workers1321.png
# hard_hat_workers1335.png
# hard_hat_workers1348.png
# hard_hat_workers1372.png
# hard_hat_workers1374.png
# hard_hat_workers1391.png
# hard_hat_workers1456.png
# hard_hat_workers1543.png
# hard_hat_workers1548.png
# hard_hat_workers1563.png
# hard_hat_workers1574.png
# hard_hat_workers1578.png
# hard_hat_workers1586.png
# hard_hat_workers1598.png
# hard_hat_workers1662.png
# hard_hat_workers1673.png
# hard_hat_workers1684.png
# hard_hat_workers1697.png
# hard_hat_workers1703.png
# hard_hat_workers1721.png
# hard_hat_workers1724.png
# hard_hat_workers1782.png
# hard_hat_workers179.png
# hard_hat_workers1796.png
# hard_hat_workers182.png
# hard_hat_workers1832.png
# hard_hat_workers184.png
# hard_hat_workers1848.png
# hard_hat_workers1854.png
# hard_hat_workers1866.png
# hard_hat_workers1877.png
# hard_hat_workers1885.png
# hard_hat_workers1918.png
# hard_hat_workers192.png
# hard_hat_workers1952.png
# hard_hat_workers1961.png
# hard_hat_workers1982.png
# hard_hat_workers2003.png
# hard_hat_workers2019.png
# hard_hat_workers2062.png
# hard_hat_workers2063.png
# hard_hat_workers2070.png
# hard_hat_workers2075.png
# hard_hat_workers2093.png
# hard_hat_workers210.png
# hard_hat_workers2113.png
# hard_hat_workers2123.png
# hard_hat_workers2131.png
# hard_hat_workers2171.png
# hard_hat_workers2200.png
# hard_hat_workers221.png
# hard_hat_workers223.png
# hard_hat_workers2244.png
# hard_hat_workers2274.png
# hard_hat_workers2289.png
# hard_hat_workers2295.png
# hard_hat_workers2309.png
# hard_hat_workers2332.png
# hard_hat_workers2340.png
# hard_hat_workers2363.png
# hard_hat_workers2365.png
# hard_hat_workers237.png
# hard_hat_workers238.png
# hard_hat_workers2408.png
# hard_hat_workers2441.png
# hard_hat_workers2454.png
# hard_hat_workers246.png
# hard_hat_workers2496.png
# hard_hat_workers2545.png
# hard_hat_workers2547.png
# hard_hat_workers2554.png
# hard_hat_workers261.png
# hard_hat_workers2617.png
# hard_hat_workers2701.png
# hard_hat_workers2705.png
# hard_hat_workers2707.png
# hard_hat_workers2713.png
# hard_hat_workers2716.png
# hard_hat_workers2728.png
# hard_hat_workers273.png
# hard_hat_workers2786.png
# hard_hat_workers2794.png
# hard_hat_workers2803.png
# hard_hat_workers2818.png
# hard_hat_workers2824.png
# hard_hat_workers2880.png
# hard_hat_workers2889.png
# hard_hat_workers2897.png
# hard_hat_workers2899.png
# hard_hat_workers292.png
# hard_hat_workers2942.png
# hard_hat_workers2950.png
# hard_hat_workers2961.png
# hard_hat_workers2983.png
# hard_hat_workers2985.png
# hard_hat_workers2998.png
# hard_hat_workers3011.png
# hard_hat_workers302.png
# hard_hat_workers3030.png
# hard_hat_workers3034.png
# hard_hat_workers3044.png
# hard_hat_workers306.png
# hard_hat_workers3076.png
# hard_hat_workers3174.png
# hard_hat_workers3180.png
# hard_hat_workers3187.png
# hard_hat_workers3221.png
# hard_hat_workers3254.png
# hard_hat_workers3262.png
# hard_hat_workers329.png
# hard_hat_workers3291.png
# hard_hat_workers3301.png
# hard_hat_workers3314.png
# hard_hat_workers3320.png
# hard_hat_workers3325.png
# hard_hat_workers3352.png
# hard_hat_workers3366.png
# hard_hat_workers3383.png
# hard_hat_workers34.png
# hard_hat_workers341.png
# hard_hat_workers3421.png
# hard_hat_workers3446.png
# hard_hat_workers3489.png
# hard_hat_workers3495.png
# hard_hat_workers3503.png
# hard_hat_workers3508.png
# hard_hat_workers3517.png
# hard_hat_workers3528.png
# hard_hat_workers3554.png
# hard_hat_workers3558.png
# hard_hat_workers3578.png
# hard_hat_workers3615.png
# hard_hat_workers3641.png
# hard_hat_workers3654.png
# hard_hat_workers3664.png
# hard_hat_workers3692.png
# hard_hat_workers3695.png
# hard_hat_workers3724.png
# hard_hat_workers3739.png
# hard_hat_workers3868.png
# hard_hat_workers3890.png
# hard_hat_workers3894.png
# hard_hat_workers3903.png
# hard_hat_workers3908.png
# hard_hat_workers3923.png
# hard_hat_workers3932.png
# hard_hat_workers4052.png
# hard_hat_workers4062.png
# hard_hat_workers4063.png
# hard_hat_workers4073.png
# hard_hat_workers4082.png
# hard_hat_workers410.png
# hard_hat_workers412.png
# hard_hat_workers4130.png
# hard_hat_workers4133.png
# hard_hat_workers4137.png
# hard_hat_workers415.png
# hard_hat_workers4238.png
# hard_hat_workers4248.png
# hard_hat_workers4275.png
# hard_hat_workers4281.png
# hard_hat_workers43.png
# hard_hat_workers4331.png
# hard_hat_workers4355.png
# hard_hat_workers4370.png
# hard_hat_workers438.png
# hard_hat_workers4410.png
# hard_hat_workers4411.png
# hard_hat_workers4417.png
# hard_hat_workers4453.png
# hard_hat_workers4504.png
# hard_hat_workers452.png
# hard_hat_workers4544.png
# hard_hat_workers4547.png
# hard_hat_workers4549.png
# hard_hat_workers4588.png
# hard_hat_workers4591.png
# hard_hat_workers4603.png
# hard_hat_workers4625.png
# hard_hat_workers4714.png
# hard_hat_workers4753.png
# hard_hat_workers4770.png
# hard_hat_workers4776.png
# hard_hat_workers4786.png
# hard_hat_workers4787.png
# hard_hat_workers4789.png
# hard_hat_workers4797.png
# hard_hat_workers4833.png
# hard_hat_workers4840.png
# hard_hat_workers4851.png
# hard_hat_workers4905.png
# hard_hat_workers4906.png
# hard_hat_workers4944.png
# hard_hat_workers4964.png
# hard_hat_workers4968.png
# hard_hat_workers4969.png
# hard_hat_workers4996.png
# hard_hat_workers509.png
# hard_hat_workers543.png
# hard_hat_workers56.png
# hard_hat_workers579.png
# hard_hat_workers581.png
# hard_hat_workers588.png
# hard_hat_workers619.png
# hard_hat_workers623.png
# hard_hat_workers630.png
# hard_hat_workers635.png
# hard_hat_workers641.png
# hard_hat_workers651.png
# hard_hat_workers663.png
# hard_hat_workers710.png
# hard_hat_workers738.png
# hard_hat_workers746.png
# hard_hat_workers750.png
# hard_hat_workers764.png
# hard_hat_workers796.png
# hard_hat_workers805.png
# hard_hat_workers832.png
# hard_hat_workers834.png
# hard_hat_workers841.png
# hard_hat_workers854.png
# hard_hat_workers870.png
# hard_hat_workers873.png
# hard_hat_workers889.png
# hard_hat_workers895.png
# hard_hat_workers902.png
# hard_hat_workers91.png
# hard_hat_workers925.png
# hard_hat_workers930.png
# hard_hat_workers952.png
# hard_hat_workers961.png
# hard_hat_workers968.png
# hard_hat_workers986.png
# hard_hat_workers99.png
